# %% [markdown]
# # Pandas Group By
# This notebook demonstrates the following features of Pandas:
# - Read selected columns (*usecols*)
# - Identify missing values (*isnull*)
# - Drop rows with missing values (*dropna*)
# - Split and summarize data by categories (*grouopby*)
# - Sort data by column values (*sort_values*)
# - Pandas visualization (*bar chart, scatter plot*)
# - Pandas visualization backend (*matplotlib, plotly*)
#
# References:
# - https://pandas.pydata.org/pandas-docs/stable/user_guide/groupby.html
# - https://www.shanelynn.ie/summarising-aggregation-and-grouping-data-in-python-pandas/

# %% [markdown]
# ## Step 1 - Set Up Environment

# %% [markdown]
# ### 1.1 - Install Plotly
# Plotly is an interactive visualization library and can be utilized as the backend
# for Pandas. Pandas support multiple visualization backends. For example, matplotlib,
# seaborn, plotly, bokeh are all supported.

# %%
# !pip install plotly
# Out:
# Collecting plotly
#   Downloading plotly-4.11.0-py2.py3-none-any.whl (13.1 MB)
#      |████████████████████████████████| 13.1 MB 21.0 MB/s eta 0:00:01
# Collecting retrying>=1.3.3
#   Downloading retrying-1.3.3.tar.gz (10 kB)
# Requirement already satisfied: six in /opt/venv/lib/python3.7/site-packages (from plotly) (1.15.0)
# Building wheels for collected packages: retrying
#   Building wheel for retrying (setup.py) ... done
#   Created wheel for retrying: filename=retrying-1.3.3-py3-none-any.whl size=11429 sha256=9bdb52940ee5fc30cc59e290058e3493695d3117505e23cb011bcc4b8a72de2c
#   Stored in directory: /home/jovyan/.cache/pip/wheels/f9/8d/8d/f6af3f7f9eea3553bc2fe6d53e4b287dad18b06a861ac56ddf
# Successfully built retrying
# Installing collected packages: retrying, plotly
# Successfully installed plotly-4.11.0 retrying-1.3.3

# %% [markdown]
# ### 1.2 - Import pandas

# %%
import pandas as pd

print(f"pd.__version__ = {pd.__version__}")
# Out:
# pd.__version__ = 1.0.5

# %% [markdown]
# ## Step 2. Read Data
# We will read data directly from the web link. Since the dataset has almost
# 2000 columns, we only read a selected list of columns of interest.

# %%
DATA_URL = "https://data.ed.gov/dataset/9dc70e6b-8426-4d71-b9d5-70ce6094a3f4/resource/823ac095-bdfc-41b0-b508-4e8fc3110082/download/most-recent-cohorts-all-data-elements-1.csv"
COLUMN_LIST = ['UNITID','INSTNM', 'CONTROL','CITY', 'STABBR','ST_FIPS', 'ZIP', 'TUITIONFEE_IN','ADM_RATE','MD_EARN_WNE_P10']

df = pd.read_csv(DATA_URL, usecols=COLUMN_LIST)
df.shape
# Out:
# (6806, 10)

# %%
df.head()
# Out:
#    UNITID                               INSTNM        CITY STABBR         ZIP  \
# 0  100654             Alabama A & M University      Normal     AL       35762
# 1  100663  University of Alabama at Birmingham  Birmingham     AL  35294-0110
# 2  100690                   Amridge University  Montgomery     AL  36117-3553
# 3  100706  University of Alabama in Huntsville  Huntsville     AL       35899
# 4  100724             Alabama State University  Montgomery     AL  36104-0271
#
#    CONTROL  ST_FIPS  ADM_RATE  TUITIONFEE_IN MD_EARN_WNE_P10
# 0        1        1    0.8986         9744.0           31000
# 1        1        1    0.9211         8568.0           41200
# 2        2        1       NaN         6900.0           39600
# 3        1        1    0.8087        10714.0           46700
# 4        1        1    0.9774        11068.0           27700

# %% [markdown]
# ## Step 3 - Cleanse Data
# The data have many missing values and other quality issues and requires cleansing.

# %% [markdown]
# ### 3.1 - Handle Missing Values
# For simplicity, we simply drop all rows that contain missing values.

# %%
df[df.notnull()]
# Out:
#         UNITID                                    INSTNM             CITY  \
# 0       100654                  Alabama A & M University           Normal
# 1       100663       University of Alabama at Birmingham       Birmingham
# 2       100690                        Amridge University       Montgomery
# 3       100706       University of Alabama in Huntsville       Huntsville
# 4       100724                  Alabama State University       Montgomery
# ...        ...                                       ...              ...
# 6801  48511112         Georgia Military College - Dublin           Dublin
# 6802  48511113        Georgia Military College - Eastman          Eastman
# 6803  48616901  American College of Barbering - Florence         Florence
# 6804  49005401      HCI College - Fort Lauderdale Campus  Fort Lauderdale
# 6805  49146401          ABC Adult School - Cabrillo Lane         Cerritos
#
#      STABBR         ZIP  CONTROL  ST_FIPS  ADM_RATE  TUITIONFEE_IN  \
# 0        AL       35762        1        1    0.8986         9744.0
# 1        AL  35294-0110        1        1    0.9211         8568.0
# 2        AL  36117-3553        2        1       NaN         6900.0
# 3        AL       35899        1        1    0.8087        10714.0
# 4        AL  36104-0271        1        1    0.9774        11068.0
# ...     ...         ...      ...      ...       ...            ...
# 6801     GA   310215149        1       13       NaN         6120.0
# 6802     GA   310236109        1       13       NaN         6120.0
# 6803     KY   410421801        3       21       NaN            NaN
# 6804     FL       33309        3       12       NaN        21420.0
# 6805     CA   907037748        1        6       NaN            NaN
#
#      MD_EARN_WNE_P10
# 0              31000
# 1              41200
# 2              39600
# 3              46700
# 4              27700
# ...              ...
# 6801             NaN
# 6802             NaN
# 6803             NaN
# 6804             NaN
# 6805             NaN
#
# [6806 rows x 10 columns]

# %%
df.isnull().sum()
# Out:
# UNITID                0
# INSTNM                0
# CITY                  0
# STABBR                0
# ZIP                   0
# CONTROL               0
# ST_FIPS               0
# ADM_RATE           4800
# TUITIONFEE_IN      2941
# MD_EARN_WNE_P10    1303
# dtype: int64

# %%
df2 = df.dropna()
df2.shape
# Out:
# (1763, 10)

# %% [markdown]
# ### 3.2 - Cleanse Median Earnings Column

# %%
# Find out how many colleges have "PrivacySuppressed" in median earnings

df2[df2["MD_EARN_WNE_P10"] == "PrivacySuppressed"]
# Out:
#       UNITID                                             INSTNM         CITY  \
# 231   110918                       California Christian College       Fresno
# 328   116846                         American Jewish University  Los Angeles
# 454   123280           Shasta Bible College and Graduate School      Redding
# 501   126076  Yeshiva Ohr Elchonon Chabad West Coast Talmudi...  Los Angeles
# 559   128586                              Bais Binyomin Academy       Monsey
# ...      ...                                                ...          ...
# 5069  451398                                Yeshiva Toras Chaim     Lakewood
# 5070  451404                       Talmudical Seminary of Bobov     Brooklyn
# 5112  454184                                 The King's College     New York
# 5170  455257                         Yeshiva of Machzikai Hadas     Brooklyn
# 5191  455770                       Providence Christian College     Pasadena
#
#      STABBR         ZIP  CONTROL  ST_FIPS  ADM_RATE  TUITIONFEE_IN  \
# 231      CA       93727        2        6    1.0000         9570.0
# 328      CA  90077-1519        2        6    0.9600        31946.0
# 454      CA       96002        2        6    1.0000        12060.0
# 501      CA  90046-7660        2        6    0.7113        14700.0
# 559      NY       10952        2       36    0.8182         8450.0
# ...     ...         ...      ...      ...       ...            ...
# 5069     NJ       08701        2       34    0.6237        12250.0
# 5070     NY       11219        2       36    0.9545        10200.0
# 5112     NY       10004        2       36    0.5382        36450.0
# 5170     NY  11219-1408        2       36    0.9529         9200.0
# 5191     CA       91101        2        6    0.8792        30370.0
#
#         MD_EARN_WNE_P10
# 231   PrivacySuppressed
# 328   PrivacySuppressed
# 454   PrivacySuppressed
# 501   PrivacySuppressed
# 559   PrivacySuppressed
# ...                 ...
# 5069  PrivacySuppressed
# 5070  PrivacySuppressed
# 5112  PrivacySuppressed
# 5170  PrivacySuppressed
# 5191  PrivacySuppressed
#
# [97 rows x 10 columns]

# %%
# Remove these colleges

df2 = df2[df2["MD_EARN_WNE_P10"] != "PrivacySuppressed"]
df2.shape
# Out:
# (1666, 10)

# %%
# Change median earnings column type from string to integer

df2["MD_EARN_WNE_P10"] = df2["MD_EARN_WNE_P10"].astype(int)
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1666 entries, 0 to 5931
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   UNITID           1666 non-null   int64
#  1   INSTNM           1666 non-null   object
#  2   CITY             1666 non-null   object
#  3   STABBR           1666 non-null   object
#  4   ZIP              1666 non-null   object
#  5   CONTROL          1666 non-null   int64
#  6   ST_FIPS          1666 non-null   int64
#  7   ADM_RATE         1666 non-null   float64
#  8   TUITIONFEE_IN    1666 non-null   float64
#  9   MD_EARN_WNE_P10  1666 non-null   int64
# dtypes: float64(2), int64(4), object(4)
# memory usage: 143.2+ KB

# %%
# Replace the Control Code with label for easier understanding 

control_dict = {
    1:"Public",            
    2:"Private, Nonprofit",
    3:"Proprietary"
}
       
df2.replace({"CONTROL": control_dict}, inplace=True)
df2.head()
# Out:
#    UNITID                               INSTNM        CITY STABBR         ZIP  \
# 0  100654             Alabama A & M University      Normal     AL       35762
# 1  100663  University of Alabama at Birmingham  Birmingham     AL  35294-0110
# 3  100706  University of Alabama in Huntsville  Huntsville     AL       35899
# 4  100724             Alabama State University  Montgomery     AL  36104-0271
# 5  100751            The University of Alabama  Tuscaloosa     AL  35487-0100
#
#   CONTROL  ST_FIPS  ADM_RATE  TUITIONFEE_IN  MD_EARN_WNE_P10
# 0  Public        1    0.8986         9744.0            31000
# 1  Public        1    0.9211         8568.0            41200
# 3  Public        1    0.8087        10714.0            46700
# 4  Public        1    0.9774        11068.0            27700
# 5  Public        1    0.5906        10780.0            44500

# %% [markdown]
# ## Step 4 - Aggregate Data

# %%
# Find out how many unique states

df2["STABBR"].nunique()
# Out:
# 54

# %%
# List all states

df2["STABBR"].unique()
# Out:
# array(['AL', 'AK', 'WA', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DE', 'DC', 'FL',
#        'GA', 'HI', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA', 'ME', 'MD',
#        'MA', 'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM',
#        'NY', 'NC', 'ND', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN',
#        'TX', 'UT', 'VT', 'VA', 'WV', 'WI', 'WY', 'PR', 'FM', 'VI'],
#       dtype=object)

# %%
# Use Named Aggregates to calculate number of colleges, mean tuition, 
# and mean earnings for each state.

gb = df2[["STABBR","TUITIONFEE_IN","MD_EARN_WNE_P10"]].groupby('STABBR').agg(
    Number_Colleges=pd.NamedAgg("STABBR", "count"),
    Mean_Tuition=pd.NamedAgg("TUITIONFEE_IN", "mean"),
    Mean_Earnings=pd.NamedAgg("MD_EARN_WNE_P10", "mean")
)

gb.head()
# Out:
#         Number_Colleges  Mean_Tuition  Mean_Earnings
# STABBR
# AK                    4  10772.250000   40075.000000
# AL                   25  15422.640000   37816.000000
# AR                   18  16004.611111   37011.111111
# AZ                   14  17156.214286   47078.571429
# CA                  101  29191.584158   50500.990099

# %%
# Reset index so that State becomes a column

gb = gb.reset_index()
gb.head()
# Out:
#   STABBR  Number_Colleges  Mean_Tuition  Mean_Earnings
# 0     AK                4  10772.250000   40075.000000
# 1     AL               25  15422.640000   37816.000000
# 2     AR               18  16004.611111   37011.111111
# 3     AZ               14  17156.214286   47078.571429
# 4     CA              101  29191.584158   50500.990099

# %%
# Rename the column

gb.rename(columns={"STABBR":"STATE"}, inplace=True)
gb.sample()
# Out:
#    STATE  Number_Colleges  Mean_Tuition  Mean_Earnings
# 48    VI                1        5235.0        32000.0

# %% [markdown]
# ## Step 5 - Visualize Data

# %% [markdown]
# ### 5.1 - Bar Charts
# We want to rank the states based on their in-state tuition and
# their potential earnings (10 years after graduation)

# %%
# Rank total number of colleges from lowest to highest by state

pd.options.plotting.backend = "matplotlib"

gb.sort_values(by="Number_Colleges").plot.bar(
    x="State", 
    y="Number_Colleges",
    figsize=(12,8)
)
# Out:
# <AxesSubplot:xlabel='State'>

# %%
# Rank in-state tution from lowest to highest

gb.sort_values(by="Mean_Tuition").plot.bar(
    x="State", 
    y="Mean_Tuition",
    figsize=(12,8)
)
# Out:
# <AxesSubplot:xlabel='State'>

# %%
# Rank potential earnings from lowest to highest

gb.sort_values(by="Mean_Earnings").plot.bar(
    x="State", 
    y="Mean_Earnings",
    figsize=(12,8)
)
# Out:
# <AxesSubplot:xlabel='State'>

# %% [markdown]
# ### 5.2 - Scatter Plot
# We want to find out if there is a relationship between tuition and potential earnings.

# %%
# First, we use matplotlib as the plotting backend.

#pd.options.plotting.backend = "matplotlib"

gb.plot.scatter(x="Mean_Tuition", y="Mean_Earnings", figsize=(10,8))
# Out:
# <AxesSubplot:xlabel='Mean_Tuition', ylabel='Mean_Earnings'>

# %%
# Here, we switch the Pandas plotting backend from matplotlib to plotly so that
# can explore interactively

pd.options.plotting.backend = "plotly"

gb.plot.scatter(x="Mean_Tuition", y="Mean_Earnings",  hover_data=["State"])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="334a68f1-4a6d-4cfa-828a-ddf55aecf80e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("334a68f1-4a6d-4cfa-828a-ddf55aecf80e")) {                    Plotly.newPlot(                        "334a68f1-4a6d-4cfa-828a-ddf55aecf80e",                        [{"customdata": [["AK"], ["AL"], ["AR"], ["AZ"], ["CA"], ["CO"], ["CT"], ["DC"], ["DE"], ["FL"], ["FM"], ["GA"], ["HI"], ["IA"], ["ID"], ["IL"], ["IN"], ["KS"], ["KY"], ["LA"], ["MA"], ["MD"], ["ME"], ["MI"], ["MN"], ["MO"], ["MS"], ["MT"], ["NC"], ["ND"], ["NE"], ["NH"], ["NJ"], ["NM"], ["NV"], ["NY"], ["OH"], ["OK"], ["OR"], ["PA"], ["PR"], ["RI"], ["SC"], ["SD"], ["TN"], ["TX"], ["UT"], ["VA"], ["VI"], ["VT"], ["WA"], ["WI"], ["WV"], ["WY"]], "hovertemplate": "Mean_Tuition=%{x}<br>Mean_Earnings=%{y}<br>State=%{customdata[0]}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "", "orientation": "v", "showlegend": false, "type": "scatter", "x": [10772.25, 15422.64, 16004.611111111111, 17156.214285714286, 29191.58415841584, 19146.8, 31429.31818181818, 38791.57142857143, 18063.5, 20882.86274509804, 4750.0, 17717.70588235294, 13510.857142857143, 29326.516129032258, 14109.857142857143, 27980.852459016394, 25268.630434782608, 20541.24, 22787.458333333332, 15234.391304347826, 36316.882352941175, 27124.041666666668, 27668.466666666667, 23134.238095238095, 26960.36111111111, 19868.0, 12715.0, 15353.875, 22590.428571428572, 11441.444444444445, 22536.29411764706, 30608.0, 26808.03125, 13530.375, 16843.0, 27327.24647887324, 25809.87671232877, 16475.944444444445, 27597.869565217392, 27592.77372262774, 5247.285714285715, 34447.2, 19249.666666666668, 16498.18181818182, 22178.64864864865, 19813.945205479453, 14674.285714285714, 23853.021276595744, 5235.0, 32521.2, 28019.04761904762, 23394.473684210527, 16846.58823529412, 5400.0], "xaxis": "x", "y": [40075.0, 37816.0, 37011.11111111111, 47078.57142857143, 50500.9900990099, 43495.0, 54027.27272727273, 57128.57142857143, 45050.0, 43184.313725490196, 19500.0, 39392.1568627451, 40328.57142857143, 43051.6129032258, 37900.0, 44411.475409836065, 42821.739130434784, 40460.0, 38083.333333333336, 40043.47826086957, 52805.882352941175, 50262.5, 45766.666666666664, 43426.19047619047, 45325.0, 42502.17391304348, 34186.666666666664, 38137.5, 38780.357142857145, 41911.11111111111, 42923.529411764706, 46491.666666666664, 52715.625, 34412.5, 44550.0, 47559.15492957747, 42412.32876712329, 39422.22222222222, 43108.69565217391, 47613.13868613139, 20067.85714285714, 52790.0, 37496.969696969696, 40463.63636363636, 39786.48648648649, 43969.86301369863, 48957.142857142855, 46176.59574468085, 32000.0, 38586.666666666664, 49242.857142857145, 43789.47368421053, 37511.76470588235, 47300.0], "yaxis": "y"}],                        {"legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444 ...

# %% [markdown]
# # The End
