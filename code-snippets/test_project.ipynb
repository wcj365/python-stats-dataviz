# %% [markdown]
# ## Test Project
# **Author**: Jay Wang
#
# **Date**: Jan 28, 2021
#
# This is just for test only. to show the class how to structure a Jupyter Notebook.

# %% [markdown]
# ## Step 1. Show the simplest Python code

# %%
print("hellow, world")
# Out:
# hellow, world

# %% [markdown]
# ## Step 2. Use Python as a calculator

# %%
5 + 6
# Out:
# 11

# %%
x = 4**3

# in Python program, you must use print() function.
# in Jupyter notebook, you just type the variable name.
# print(x)  
x
# Out:
# 64
