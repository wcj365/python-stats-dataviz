# %% [markdown]
# <a href="https://colab.research.google.com/github/wcj365/python-stats-dataviz/blob/master/examples/umbc690_fall24_survey.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exploring the Student Survey

# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/wcj365/python-stats-dataviz/master/data/UMBC%20DATA%20690%20FALL%202024%20DR%20WANG%20Student%20Survey.csv")
print(df.shape)
# Out:
# (21, 13)

# %%
df.head(2)
# Out:
#                    Timestamp           1. My primary educational background  \
# 0  2024/08/18 8:33:50 PM AST  STEM (Science, Technology, Engineering, Math)
# 1  2024/08/18 8:33:54 PM AST  STEM (Science, Technology, Engineering, Math)
#
#   2. My primary job function 3. My level of computer programing knowledge  \
# 0          Full-time Student                                 Intermediate
# 1          Full-time Student                                 Intermediate
#
#   4. My level of Python progrmming knowledge  \
# 0                               Intermediate
# 1                               Intermediate
#
#   5. My level of Statistics knowledge 6. My Familarity with GitHub  \
# 0                        Intermediate    I use GitHub occasionally
# 1                        Intermediate    I use GitHub occasionally
#
#   7. My gender 8. My Birth Year  \
# 0         Male             2000
# 1         Male             2002
#
#   9. What do you enjoy doing in your leisure time?  \
# ...

# %%
df.sample(5)
# Out:
#                      Timestamp  \
# 18   2024/08/28 6:59:16 PM AST
# 2   2024/08/19 10:33:47 AM AST
# 19   2024/08/28 7:04:43 PM AST
# 17   2024/08/28 6:56:33 PM AST
# 14   2024/08/28 5:33:53 PM AST
#
#                  1. My primary educational background  \
# 18      STEM (Science, Technology, Engineering, Math)
# 2       STEM (Science, Technology, Engineering, Math)
# 19      STEM (Science, Technology, Engineering, Math)
# 17  Criminal Justice with some Software Engineerin...
# 14      STEM (Science, Technology, Engineering, Math)
#
#    2. My primary job function 3. My level of computer programing knowledge  \
# 18          Full-time Student                                 Intermediate
# 2           Full-time Student                                 Intermediate
# 19          Full-time Student                                 Intermediate
# 17          Full-time Student                                     Beginner
# ...

# %%
df["8. My Birth Year"]
# Out:
# 0           2000
# 1           2002
# 2           1997
# 3      7/21/1999
# 4           2000
# 5           2001
# 6           2000
# 7           1999
# 8           1978
# 9           2000
# 10          1999
# 11    11/17/2000
# 12          1998
# 13      3/1/2001
# 14          2001
# 15          2000
# 16          2002
# 17          1992
# 18     12/6/2001
# 19          1997
# 20          1999
# Name: 8. My Birth Year, dtype: object

# %%
years = df["8. My Birth Year"].tolist()
years
# Out:
# ['2000',
#  '2002',
#  '1997',
#  '7/21/1999',
#  '2000',
#  '2001',
#  '2000',
#  '1999',
#  '1978',
#  '2000',
#  '1999',
#  '11/17/2000',
#  '1998',
#  '3/1/2001',
#  '2001',
#  '2000',
#  '2002',
#  '1992',
#  '12/6/2001',
#  '1997',
#  '1999']

# %%
year = "7/21/1999"

year[-4:]
# Out:
# '1999'

# %%
sum = 0
for year in years:
    clean_year = year[-4:]
    sum = sum + 2024 - int(clean_year)

sum / len(years)
# Out:
# 25.61904761904762

# %%
len(years)
# Out:
# 21
