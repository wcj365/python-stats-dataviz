# %% [markdown]
# ### Pandas Plotting
# https://pandas.pydata.org/pandas-docs/stable/reference/frame.html#plotting

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Scatter plot

Data = {'Unemployment_Rate': [6.1,5.8,5.7,5.7,5.8,5.6,5.5,5.3,5.2,5.2],
        'Stock_Index_Price': [1500,1520,1525,1523,1515,1540,1545,1560,1555,1565]
       }
df = pd.DataFrame(Data,columns=['Unemployment_Rate','Stock_Index_Price'])

fig, ax = plt.subplots(1,2, figsize=(10,6))
ax[0].set_title("Unemployment Rate vs Stock Price")


df.plot.scatter(x ='Unemployment_Rate', y='Stock_Index_Price', ax=ax[0])

# %%
# Bar Plot

Data = {'Country': ['USA','Canada','Germany','UK','France'],
        'GDP_Per_Capita': [45000,42000,52000,49000,47000]
       }

df = pd.DataFrame(Data,columns=['Country','GDP_Per_Capita'])

fig, ax = plt.subplots(figsize=(10,10))
ax.set_title("Per Capita GDP by Country")
df.plot.bar(x ='Country', y='GDP_Per_Capita',ax=ax)

# %%
# Line Plot

Data = {'Year': [1920,1930,1940,1950,1960,1970,1980,1990,2000,2010],
        'Unemployment_Rate': [9.8,12,8,7.2,6.9,7,6.5,6.2,5.5,6.3]
       } 
df = pd.DataFrame(Data,columns=['Year','Unemployment_Rate'])

fig, ax = plt.subplots(figsize=(10,10))
ax.set_title("Unemployment Rate Overtime")
df.plot.line(x ='Year', y='Unemployment_Rate', ax=ax)

# %%
# Pie Plot

Data = {'Tasks': [300,500,700]}
df = pd.DataFrame(Data,columns=['Tasks'],index = ['Tasks Pending','Tasks Ongoing','Tasks Completed'])

fig, ax = plt.subplots(figsize=(10,10))
ax.set_title("Task Status")
df.plot.pie(y='Tasks',autopct='%.2f%%',startangle=90,  ax=ax)
