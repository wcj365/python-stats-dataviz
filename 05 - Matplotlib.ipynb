# %%
import matplotlib.pyplot as plt
import pandas as pd
# https://matplotlib.org/3.1.1/api/axes_api.html#plotting

# %%
# Object-oriented Style of programming - Preferred

Unemployment_Rate = [6.1,5.8,5.7,5.7,5.8,5.6,5.5,5.3,5.2,5.2]
Stock_Index_Price = [1500,1520,1525,1523,1515,1540,1545,1560,1555,1565]

fig, ax = plt.subplots(2,4, figsize=(16,16))  
ax[1,1].scatter(Unemployment_Rate, Stock_Index_Price, color='green')
ax[1,1].set_title('Unemployment Rate Vs Stock Index Price', fontsize=14)
ax[1,1].set_xlabel('Unemployment Rate', fontsize=14)
ax[1,1].set_ylabel('Stock Index Price', fontsize=14)
#ax.grid(True)
# Out:
# Text(0, 0.5, 'Stock Index Price')

# %%
# Procedural style of program - not preferred

plt.scatter(Unemployment_Rate, Stock_Index_Price, color='green')
plt.title('Unemployment Rate Vs Stock Index Price', fontsize=14)
plt.xlabel('Unemployment Rate', fontsize=14)
plt.ylabel('Stock Index Price', fontsize=14)
plt.grid(True)
plt.show()

# %%
# Object-oriented Style of programming - Preferred

Year = [1920,1930,1940,1950,1960,1970,1980,1990,2000,2010]
Unemployment_Rate = [9.8,12,8,7.2,6.9,7,6.5,6.2,5.5,6.3]

fig, ax = plt.subplots(figsize=(10,10))

ax.plot(Year, Unemployment_Rate, color='red', marker='o')
ax.set_title('Unemployment Rate Vs Year', fontsize=14)
ax.set_xlabel('Year', fontsize=14)
ax.set_ylabel('Unemployment Rate', fontsize=14)
ax.grid(True)

# %%
# Procedural style of program - not preferred

Year = [1920,1930,1940,1950,1960,1970,1980,1990,2000,2010]
Unemployment_Rate = [9.8,12,8,7.2,6.9,7,6.5,6.2,5.5,6.3]
  
plt.plot(Year, Unemployment_Rate, color='red', marker='o')
plt.title('Unemployment Rate Vs Year', fontsize=14)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Unemployment Rate', fontsize=14)
plt.grid(True)

# %%
# Object-oriented Style of programming - Preferred

Country = ['USA','Canada','Germany','UK','France']
GDP_Per_Capita = [45000,42000,52000,49000,47000]

fig, ax = plt.subplots(figsize=(10,10))

ax.bar(Country, GDP_Per_Capita, color='teal')
ax.set_title('Country Vs GDP Per Capita', fontsize=14)
ax.set_xlabel('Country', fontsize=14)
ax.set_ylabel('GDP Per Capita', fontsize=14)
ax.grid(True)

# %%
# Procedural style of program - not preferred
Country = ['USA','Canada','Germany','UK','France']
GDP_Per_Capita = [45000,42000,52000,49000,47000]

plt.bar(Country, GDP_Per_Capita, color='teal')
plt.title('Country Vs GDP Per Capita', fontsize=14)
plt.xlabel('Country', fontsize=14)
plt.ylabel('GDP Per Capita', fontsize=14)
plt.show()

# %%
# Object-oriented Style of programming - Preferred
langs = ['C', 'C++', 'Java', 'Python', 'PHP']
students = [23,17,35,29,12]

fig, ax = plt.subplots(figsize=(10,10))
ax.set_title("Languages used by Students")
ax.pie(x=students, labels=langs, startangle=90, autopct='%.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x171b0d64828>,
# ...
#  [Text(0.8934077559145442, 0.6417340427869932, 'C'),
#   Text(-0.14850004338941242, 1.0899301524012182, 'C++'),
#   Text(-1.0995966158072983, 0.02978728764317382, 'Java'),
#   Text(0.1485000433894123, -1.0899301524012182, 'Python'),
#   Text(1.042418501058071, -0.3512316452881833, 'PHP')],
#  [Text(0.48731332140793315, 0.35003675061108713, '19.83%'),
#   Text(-0.08100002366695222, 0.5945073558552099, '14.66%'),
#   Text(-0.5997799722585262, 0.01624761144173117, '30.17%'),
#   Text(0.08100002366695215, -0.5945073558552099, '25.00%'),
#   Text(0.5685919096680387, -0.19158089742991813, '10.34%')])
