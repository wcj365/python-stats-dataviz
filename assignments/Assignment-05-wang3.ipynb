# %% [markdown]
# ### Assignment 5
#
# You will unzip the zip file manually in preparation for this assignment.
#
# The link to the zip file is (you have already used it in your assignment 3):
#
# https://ed-public-download.app.cloud.gov/downloads/CollegeScorecard_Raw_Data.zip
#
# After unzipping, You will have all files in one folder named "CollegeScorecard_Raw_Data"
#
# The folder contains the yearly data files from 1996 to 2017 school years.
#
# Your Jupyter Notebook file should not be in the CollegeScorecard_Raw_Data folder.
#
# I suggest you create a new folder call "Assignment4" and place the Notebook file and the data folder under it.
#
# Assignment4/
#     - Jay.ipynb
#     - CollegeScorecard_Raw_Data/
#         - ...
#         - 'MERGED1996_97_PP.csv',
#         - 'MERGED2015_16_PP.csv',
#         - ...
#         - 'MERGED2017_18_PP.csv'

# %%
# <1> 
# Import libraries
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# <2>
# Find out what files are in the folder and assign the list of files to a variable for later processing
# you would need to import a library call os which stands for operating system. so place that import statement in previous cell.
# # os library also has method getcwd() to get the current working directory. since your notebook and your data files are not in 
# the same folder, you want to make sure what is the current working folder and how to access a data file in a different folder
# display the current workin directory
os.getcwd()
# Out:
# 'C:\\Users\\jay\\apps\\DATA690-1\\Assignment #5'

# %%
# <3> 
# os library has a method call listdir which generates a list of files in a directory/folder
# use this method to assign the contents of the data folder to a variable and display it
files = os.listdir(path='CollegeScorecard_Raw_Data')
files
# Out:
# ['Crosswalks.zip',
#  'data.yaml',
#  'MERGED1996_97_PP.csv',
#  'MERGED1997_98_PP.csv',
#  'MERGED1998_99_PP.csv',
#  'MERGED1999_00_PP.csv',
#  'MERGED2000_01_PP.csv',
#  'MERGED2001_02_PP.csv',
#  'MERGED2002_03_PP.csv',
#  'MERGED2003_04_PP.csv',
#  'MERGED2004_05_PP.csv',
#  'MERGED2005_06_PP.csv',
#  'MERGED2006_07_PP.csv',
#  'MERGED2007_08_PP.csv',
#  'MERGED2008_09_PP.csv',
#  'MERGED2009_10_PP.csv',
#  'MERGED2010_11_PP.csv',
#  'MERGED2011_12_PP.csv',
#  'MERGED2012_13_PP.csv',
#  'MERGED2013_14_PP.csv',
#  'MERGED2014_15_PP.csv',
#  'MERGED2015_16_PP.csv',
#  'MERGED2016_17_PP.csv',
#  'MERGED2017_18_PP.csv']

# %%
# <4> 
# The folder contains a couple of files that are not the yearly data files
# write code to remove the unwanted files from the list (Note: not from the folder in your drive)
# hint: use pop or remove functions of a list. pop and remove work differently though.
files.pop(0)
files
# Out:
# ['data.yaml',
#  'MERGED1996_97_PP.csv',
#  'MERGED1997_98_PP.csv',
#  'MERGED1998_99_PP.csv',
#  'MERGED1999_00_PP.csv',
#  'MERGED2000_01_PP.csv',
#  'MERGED2001_02_PP.csv',
#  'MERGED2002_03_PP.csv',
#  'MERGED2003_04_PP.csv',
#  'MERGED2004_05_PP.csv',
#  'MERGED2005_06_PP.csv',
#  'MERGED2006_07_PP.csv',
#  'MERGED2007_08_PP.csv',
#  'MERGED2008_09_PP.csv',
#  'MERGED2009_10_PP.csv',
#  'MERGED2010_11_PP.csv',
#  'MERGED2011_12_PP.csv',
#  'MERGED2012_13_PP.csv',
#  'MERGED2013_14_PP.csv',
#  'MERGED2014_15_PP.csv',
#  'MERGED2015_16_PP.csv',
#  'MERGED2016_17_PP.csv',
#  'MERGED2017_18_PP.csv']

# %%
files.pop(0)
files
# Out:
# ['MERGED1996_97_PP.csv',
#  'MERGED1997_98_PP.csv',
#  'MERGED1998_99_PP.csv',
#  'MERGED1999_00_PP.csv',
#  'MERGED2000_01_PP.csv',
#  'MERGED2001_02_PP.csv',
#  'MERGED2002_03_PP.csv',
#  'MERGED2003_04_PP.csv',
#  'MERGED2004_05_PP.csv',
#  'MERGED2005_06_PP.csv',
#  'MERGED2006_07_PP.csv',
#  'MERGED2007_08_PP.csv',
#  'MERGED2008_09_PP.csv',
#  'MERGED2009_10_PP.csv',
#  'MERGED2010_11_PP.csv',
#  'MERGED2011_12_PP.csv',
#  'MERGED2012_13_PP.csv',
#  'MERGED2013_14_PP.csv',
#  'MERGED2014_15_PP.csv',
#  'MERGED2015_16_PP.csv',
#  'MERGED2016_17_PP.csv',
#  'MERGED2017_18_PP.csv']

# %%
# <5> 
# Now that you have a clean list of the yearly files, you want to loop through them
# and read them into a dataframe one at a time. You only load three columns: UNITID, ADM_RATE, and TUITIONFEE_IN
# You also want to add a new column call "YEAR" to differentiate the data frames from each other.
# You would use an empty list and append the yearly dataframes to the list.
# After all data files are loaded and appended to the list, you would use Pandas to concatenate them into a 
# new single data frame.
# Note: this exercise incorporates many techques we learned before
# - list (creating an empty, append an item to the list)
# - for loop 
# - read only the needed columns from a file (using usecols option)
# - add a new column to a data frame
# - concatenate multiple dataframes into a single one
# This exercise may appear a big challenging but it worths the effort. You will learn a lot and  love it. I promise.

cols = ['UNITID','ADM_RATE','TUITIONFEE_IN']
path='CollegeScorecard_Raw_Data/'
df_list = []
for file in files:
    tempdf = pd.read_csv(path+file, usecols=cols)
    tempdf['YEAR']= file[6:10]
    df_list.append(tempdf)
df = pd.concat(df_list)
df
# Out:
#         UNITID  ADM_RATE  TUITIONFEE_IN  YEAR
# 0       100636       NaN            NaN  1996
# 1       100654       NaN            NaN  1996
# 2       100663       NaN            NaN  1996
# 3       100672       NaN            NaN  1996
# 4       100690       NaN            NaN  1996
# 5       100706       NaN            NaN  1996
# 6       100724       NaN            NaN  1996
# 7       100751       NaN            NaN  1996
# 8       100760       NaN            NaN  1996
# 9       100812       NaN            NaN  1996
# 10      100830       NaN            NaN  1996
# 11      100858       NaN            NaN  1996
# 12      100919       NaN            NaN  1996
# 13      100937       NaN            NaN  1996
# 14      100964       NaN            NaN  1996
# 15      101019       NaN            NaN  1996
# 16      101028       NaN            NaN  1996
# 17      101037       NaN            NaN  1996
# 18      101073       NaN            NaN  1996
# 19      101107       NaN            NaN  1996
# 20      101116       NaN            NaN  1996
# 21      101143       NaN            NaN  1996
# 22      101161       NaN            NaN  1996
# 23      101189       NaN            NaN  1996
# 24      101198       NaN            NaN  1996
# 25      101204       NaN            NaN  1996
# 26      101213       NaN            NaN  1996
# 27      101231       NaN            NaN  1996
# 28      101240       NaN            NaN  1996
# 29      101268       NaN            NaN  1996
# ...        ...       ...            ...   ...
# 7085  47503301       NaN            NaN  2017
# 7086  47503302       NaN            NaN  2017
# 7087  47503303       NaN            NaN  2017
# 7088  47503304       NaN            NaN  2017
# 7089  47503305       NaN            NaN  2017
# 7090  47503306       NaN            NaN  2017
# 7091  47503307       NaN            NaN  2017
# 7092  47503308       NaN            NaN  2017
# 7093  47503309       NaN            NaN  2017
# 7094  47503310       NaN            NaN  2017
# 7095  47503311       NaN            NaN  2017
# 7096  47503312       NaN            NaN  2017
# 7097  47503313       NaN            NaN  2017
# 7098  47647001       NaN            NaN  2017
# 7099  47662901       NaN            NaN  2017
# 7100  47691101       NaN            NaN  2017
# 7101  48065701       NaN        10935.0  2017
# 7102  48079001       NaN            NaN  2017
# 7103  48092101       NaN            NaN  2017
# 7104  48133101       NaN            NaN  2017
# 7105  48154401       NaN            NaN  2017
# 7106  48305401       NaN            NaN  2017
# 7107  48312401       NaN            NaN  2017
# 7108  48312402       NaN         6904.0  2017
# 7109  48312403       NaN            NaN  2017
# 7110  48312404       NaN            NaN  2017
# 7111  48387801       NaN            NaN  2017
# 7112  48400201       NaN            NaN  2017
# 7113  48778201       NaN            NaN  2017
# 7114  49005401       NaN        22575.0  2017
#
# [154285 rows x 4 columns]

# %%
df = df.sort_values(['YEAR','UNITID'], ascending=[True,False])

# %%
df = df.reset_index(drop=True)
df
# Out:
#         UNITID  ADM_RATE  TUITIONFEE_IN  YEAR
# 0       428444       NaN            NaN  1996
# 1       428392       NaN            NaN  1996
# 2       428374       NaN            NaN  1996
# 3       428365       NaN            NaN  1996
# 4       428347       NaN            NaN  1996
# 5       428329       NaN            NaN  1996
# 6       428310       NaN            NaN  1996
# 7       428301       NaN            NaN  1996
# 8       428277       NaN            NaN  1996
# 9       428222       NaN            NaN  1996
# 10      428198       NaN            NaN  1996
# 11      428189       NaN            NaN  1996
# 12      428170       NaN            NaN  1996
# 13      428161       NaN            NaN  1996
# 14      428152       NaN            NaN  1996
# 15      428143       NaN            NaN  1996
# 16      428134       NaN            NaN  1996
# 17      428125       NaN            NaN  1996
# 18      428091       NaN            NaN  1996
# 19      428082       NaN            NaN  1996
# 20      428073       NaN            NaN  1996
# 21      428064       NaN            NaN  1996
# 22      428055       NaN            NaN  1996
# 23      428046       NaN            NaN  1996
# 24      428037       NaN            NaN  1996
# 25      428028       NaN            NaN  1996
# 26      428000       NaN            NaN  1996
# 27      427982       NaN            NaN  1996
# 28      427973       NaN            NaN  1996
# 29      427964       NaN            NaN  1996
# ...        ...       ...            ...   ...
# 154255  101505       NaN         4500.0  2017
# 154256  101499       NaN         4088.0  2017
# 154257  101480    0.5402         8166.0  2017
# 154258  101471       NaN         4968.0  2017
# 154259  101462       NaN         4410.0  2017
# 154260  101453    1.0000        11232.0  2017
# 154261  101435    0.5598        26400.0  2017
# 154262  101365    0.7570        13850.0  2017
# 154263  101301       NaN         4140.0  2017
# 154264  101295       NaN         3726.0  2017
# 154265  101286       NaN         4380.0  2017
# 154266  101277       NaN            NaN  2017
# 154267  101240       NaN         3600.0  2017
# 154268  101189    0.5101        20970.0  2017
# 154269  101161       NaN         4380.0  2017
# 154270  101143       NaN         4440.0  2017
# 154271  101116       NaN        17014.0  2017
# 154272  101073       NaN        10320.0  2017
# 154273  101028       NaN         4314.0  2017
# 154274  100937    0.6186        35804.0  2017
# 154275  100858    0.8393        10968.0  2017
# 154276  100830    0.8254         8020.0  2017
# 154277  100812       NaN            NaN  2017
# 154278  100760       NaN         4440.0  2017
# 154279  100751    0.5330        10780.0  2017
# 154280  100724    0.9787        11068.0  2017
# 154281  100706    0.8123        10280.0  2017
# 154282  100690       NaN         6900.0  2017
# 154283  100663    0.9181         8328.0  2017
# 154284  100654    0.9027         9857.0  2017
#
# [154285 rows x 4 columns]

# %%
# <6> 
# explore the new dataframe (# of observations, varibles, head, tail, sample, missing values, statistics,etc.)
df.describe()
# Out:
#              UNITID      ADM_RATE  TUITIONFEE_IN
# count  1.542850e+05  42583.000000   74895.000000
# mean   9.008680e+05      0.694096   11490.479631
# std    4.413698e+06      0.215820    9754.367858
# min    1.006360e+05      0.000000       0.000000
# 25%    1.628300e+05      0.555600    3684.500000
# 50%    2.122760e+05      0.718100    9200.000000
# 75%    4.060600e+05      0.857100   15995.000000
# max    4.900540e+07      1.000000   74787.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 154282 entries, 0 to 154281
# Data columns (total 4 columns):
# UNITID           154282 non-null int64
# ADM_RATE         42583 non-null float64
# TUITIONFEE_IN    74888 non-null float64
# YEAR             154282 non-null object
# dtypes: float64(2), int64(1), object(1)
# memory usage: 4.7+ MB

# %%
df.head(10)
# Out:
#    UNITID  ADM_RATE  TUITIONFEE_IN  YEAR
# 0  428444       NaN            NaN  1996
# 1  428392       NaN            NaN  1996
# 2  428374       NaN            NaN  1996
# 3  428365       NaN            NaN  1996
# 4  428347       NaN            NaN  1996
# 5  428329       NaN            NaN  1996
# 6  428310       NaN            NaN  1996
# 7  428301       NaN            NaN  1996
# 8  428277       NaN            NaN  1996
# 9  428222       NaN            NaN  1996

# %%
df.tail(10)
# Out:
#         UNITID  ADM_RATE  TUITIONFEE_IN  YEAR
# 154272  100858    0.8393        10968.0  2017
# 154273  100830    0.8254         8020.0  2017
# 154274  100812       NaN            NaN  2017
# 154275  100760       NaN         4440.0  2017
# 154276  100751    0.5330        10780.0  2017
# 154277  100724    0.9787        11068.0  2017
# 154278  100706    0.8123        10280.0  2017
# 154279  100690       NaN         6900.0  2017
# 154280  100663    0.9181         8328.0  2017
# 154281  100654    0.9027         9857.0  2017

# %%
df.sample(10)
# Out:
#         UNITID  ADM_RATE  TUITIONFEE_IN  YEAR
# 115511  154855       NaN        19050.0  2012
# 59602   446394       NaN         4890.0  2005
# 131131  153339       NaN            NaN  2014
# 87896   445559       NaN        11450.0  2009
# 104652  245421       NaN         9875.0  2011
# 82754   230144       NaN            NaN  2008
# 112363  363916    0.9833         4850.0  2012
# 133131  482653    0.9000        19568.0  2015
# 11045   175519       NaN            NaN  1997
# 31155   160038       NaN            NaN  2000

# %%
df.isna().sum()
# Out:
# UNITID                0
# ADM_RATE         111699
# TUITIONFEE_IN     79394
# YEAR                  0
# dtype: int64

# %% [markdown]
# #### Wow, lots of NaN values!
# The only numbers that should have 0 NaNs are UNITID and YEAR, which matches up with what I see here.

# %%
# <7>
# the dataframe contains 22 years of data of all U.S. colleges.
# let's just look at UMBC
# filte/query the dataframe to retrieve only rows that belong to UMBC
# save the UMBC data to a new data frame. using a new variable 
# so that the old big data frame is still available for later use.
umbc = df[df['UNITID']==163268]
umbc
# Out:
#         UNITID  ADM_RATE  TUITIONFEE_IN  YEAR
# 4710    163268       NaN            NaN  1996
# 11512   163268       NaN            NaN  1997
# 18048   163268       NaN            NaN  1998
# 24523   163268       NaN            NaN  1999
# 31038   163268       NaN         5490.0  2000
# 37646   163268    0.6551         5910.0  2001
# 44210   163268    0.6327         6362.0  2002
# 50815   163268    0.5757         7388.0  2003
# 57514   163268    0.7014         8020.0  2004
# 64351   163268    0.7143         8520.0  2005
# 71222   163268    0.7153         8622.0  2006
# 78127   163268    0.6895         8708.0  2007
# 85115   163268    0.7174         8780.0  2008
# 92285   163268    0.6890         8872.0  2009
# 99732   163268    0.6589         9171.0  2010
# 107422  163268    0.6081         9467.0  2011
# 115249  163268    0.6035         9764.0  2012
# 123083  163268    0.6315        10068.0  2013
# 130804  163268    0.5961        10384.0  2014
# 138454  163268    0.5942        11006.0  2015
# 145673  163268    0.5683        11264.0  2016
# 152806  163268    0.6021        11518.0  2017

# %%
# <8>
# Explore this UMBC dataframe (# of observations, varibles, head, tail, sample, missing values, statistics,etc.)
umbc.describe()
# Out:
#          UNITID   ADM_RATE  TUITIONFEE_IN
# count      22.0  17.000000      18.000000
# mean   163268.0   0.644300    8850.777778
# std         0.0   0.052013    1747.028925
# min    163268.0   0.568300    5490.000000
# 25%    163268.0   0.602100    8145.000000
# 50%    163268.0   0.632700    8826.000000
# 75%    163268.0   0.689500    9992.000000
# max    163268.0   0.717400   11518.000000

# %%
umbc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22 entries, 4710 to 152806
# Data columns (total 4 columns):
# UNITID           22 non-null int64
# ADM_RATE         17 non-null float64
# TUITIONFEE_IN    18 non-null float64
# YEAR             22 non-null object
# dtypes: float64(2), int64(1), object(1)
# memory usage: 880.0+ bytes

# %%
umbc.head(3)
# Out:
#        UNITID  ADM_RATE  TUITIONFEE_IN  YEAR
# 4710   163268       NaN            NaN  1996
# 11512  163268       NaN            NaN  1997
# 18048  163268       NaN            NaN  1998

# %%
umbc.tail(3)
# Out:
#         UNITID  ADM_RATE  TUITIONFEE_IN  YEAR
# 138454  163268    0.5942        11006.0  2015
# 145673  163268    0.5683        11264.0  2016
# 152806  163268    0.6021        11518.0  2017

# %%
umbc.sample(3)
# Out:
#         UNITID  ADM_RATE  TUITIONFEE_IN  YEAR
# 4710    163268       NaN            NaN  1996
# 145673  163268    0.5683        11264.0  2016
# 130804  163268    0.5961        10384.0  2014

# %%
umbc.isna().sum()
# Out:
# UNITID           0
# ADM_RATE         5
# TUITIONFEE_IN    4
# YEAR             0
# dtype: int64

# %%
# <9> 
# Plot UMBC's in-state tution overtime from 1996 to 2017.


fig, ax = plt.subplots(figsize=(10,10))  
ax.scatter(umbc['YEAR'], umbc['TUITIONFEE_IN'], color='blue')
ax.set_title('In-State Tuition for UMBC 1996-2017', fontsize=14)
#ax.set_ylim([0,55000])
ax.set_xlabel('Year', fontsize=14)
ax.set_ylabel('Tuition', fontsize=14)
ax.grid(True)

# %%
# <10>
# go back to 5/6/7 and modify the code to look at Johns Hopskins University instead.
# (No code to write here, you just modify the previous cells)

# %%
jhu = df[df['UNITID']==162928]
jhu
# Out:
#         UNITID  ADM_RATE  TUITIONFEE_IN  YEAR
# 4721    162928       NaN            NaN  1996
# 11522   162928       NaN            NaN  1997
# 18057   162928       NaN            NaN  1998
# 24532   162928       NaN            NaN  1999
# 31047   162928       NaN        24930.0  2000
# 37655   162928    0.3431        26210.0  2001
# 44219   162928    0.3506        27390.0  2002
# 50823   162928    0.3060        28730.0  2003
# 57521   162928    0.3071        30140.0  2004
# 64358   162928    0.3509        31620.0  2005
# 71229   162928    0.2792        33900.0  2006
# 78134   162928    0.2571        35900.0  2007
# 85122   162928    0.2609        37700.0  2008
# 92292   162928    0.2782        39150.0  2009
# 99739   162928    0.2225        40680.0  2010
# 107429  162928    0.1940        42280.0  2011
# 115256  162928    0.1843        43390.0  2012
# 123090  162928    0.1813        45470.0  2013
# 130811  162928    0.1608        47060.0  2014
# 138461  162928    0.1412        48710.0  2015
# 145680  162928    0.1284        50410.0  2016
# 152811  162928    0.1254        52170.0  2017

# %%
jhu.describe()
# Out:
#          UNITID   ADM_RATE  TUITIONFEE_IN
# count      22.0  17.000000      18.000000
# mean   162928.0   0.239471   38102.222222
# std         0.0   0.078395    8728.590315
# min    162928.0   0.125400   24930.000000
# 25%    162928.0   0.181300   30510.000000
# 50%    162928.0   0.257100   38425.000000
# 75%    162928.0   0.306000   44950.000000
# max    162928.0   0.350900   52170.000000

# %%
jhu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22 entries, 4721 to 152811
# Data columns (total 4 columns):
# UNITID           22 non-null int64
# ADM_RATE         17 non-null float64
# TUITIONFEE_IN    18 non-null float64
# YEAR             22 non-null object
# dtypes: float64(2), int64(1), object(1)
# memory usage: 880.0+ bytes

# %%
jhu.head(3)
# Out:
#        UNITID  ADM_RATE  TUITIONFEE_IN  YEAR
# 4721   162928       NaN            NaN  1996
# 11522  162928       NaN            NaN  1997
# 18057  162928       NaN            NaN  1998

# %%
jhu.tail(3)
# Out:
#         UNITID  ADM_RATE  TUITIONFEE_IN  YEAR
# 138461  162928    0.1412        48710.0  2015
# 145680  162928    0.1284        50410.0  2016
# 152811  162928    0.1254        52170.0  2017

# %%
jhu.sample(3)
# Out:
#        UNITID  ADM_RATE  TUITIONFEE_IN  YEAR
# 4721   162928       NaN            NaN  1996
# 50823  162928     0.306        28730.0  2003
# 18057  162928       NaN            NaN  1998

# %%
jhu.isna().sum()
# Out:
# UNITID           0
# ADM_RATE         5
# TUITIONFEE_IN    4
# YEAR             0
# dtype: int64

# %%
jhu_tuition = jhu['TUITIONFEE_IN']
jhu_year = jhu['YEAR']

fig, ax = plt.subplots(figsize=(10,10))  
ax.scatter(jhu['YEAR'], jhu['TUITIONFEE_IN'], color='green')
ax.set_title('In-State Tuition for JHU 1996-2017', fontsize=14)
#ax.set_ylim([0,55000])
ax.set_xlabel('Year', fontsize=14)
ax.set_ylabel('Tuition', fontsize=14)
ax.grid(True)

# %%
# <11> 
# Now, we like to compare UMBC and JHU
# filte/query the dataframe to retrieve only rows that belong to UMBC orJHU
# save the UMNC/JHU data to a new data frame. using a new variable 
# so that the old big data frame is still available for later use.
md = df[(df['UNITID']==163268)| (df['UNITID']==162928)]
md
# Out:
#         UNITID  ADM_RATE  TUITIONFEE_IN  YEAR
# 4710    163268       NaN            NaN  1996
# 4721    162928       NaN            NaN  1996
# 11512   163268       NaN            NaN  1997
# 11522   162928       NaN            NaN  1997
# 18048   163268       NaN            NaN  1998
# 18057   162928       NaN            NaN  1998
# 24523   163268       NaN            NaN  1999
# 24532   162928       NaN            NaN  1999
# 31038   163268       NaN         5490.0  2000
# 31047   162928       NaN        24930.0  2000
# 37646   163268    0.6551         5910.0  2001
# 37655   162928    0.3431        26210.0  2001
# 44210   163268    0.6327         6362.0  2002
# 44219   162928    0.3506        27390.0  2002
# 50815   163268    0.5757         7388.0  2003
# 50823   162928    0.3060        28730.0  2003
# 57514   163268    0.7014         8020.0  2004
# 57521   162928    0.3071        30140.0  2004
# 64351   163268    0.7143         8520.0  2005
# 64358   162928    0.3509        31620.0  2005
# 71222   163268    0.7153         8622.0  2006
# 71229   162928    0.2792        33900.0  2006
# 78127   163268    0.6895         8708.0  2007
# 78134   162928    0.2571        35900.0  2007
# 85115   163268    0.7174         8780.0  2008
# 85122   162928    0.2609        37700.0  2008
# 92285   163268    0.6890         8872.0  2009
# 92292   162928    0.2782        39150.0  2009
# 99732   163268    0.6589         9171.0  2010
# 99739   162928    0.2225        40680.0  2010
# 107422  163268    0.6081         9467.0  2011
# 107429  162928    0.1940        42280.0  2011
# 115249  163268    0.6035         9764.0  2012
# 115256  162928    0.1843        43390.0  2012
# 123083  163268    0.6315        10068.0  2013
# 123090  162928    0.1813        45470.0  2013
# 130804  163268    0.5961        10384.0  2014
# 130811  162928    0.1608        47060.0  2014
# 138454  163268    0.5942        11006.0  2015
# 138461  162928    0.1412        48710.0  2015
# 145673  163268    0.5683        11264.0  2016
# 145680  162928    0.1284        50410.0  2016
# 152806  163268    0.6021        11518.0  2017
# 152811  162928    0.1254        52170.0  2017

# %%
# <12>
# Explore the new dataframe (#of observations, varibles, head, tail, sample, missing values, statistics,etc.)
md.describe()
# Out:
#               UNITID   ADM_RATE  TUITIONFEE_IN
# count      44.000000  34.000000      36.000000
# mean   163098.000000   0.441885   23476.500000
# std       171.965383   0.215650   16078.299307
# min    162928.000000   0.125400    5490.000000
# 25%    162928.000000   0.258050    8849.000000
# 50%    163098.000000   0.459600   18224.000000
# 75%    163268.000000   0.632400   38062.500000
# max    163268.000000   0.717400   52170.000000

# %%
md.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44 entries, 4710 to 152808
# Data columns (total 4 columns):
# UNITID           44 non-null int64
# ADM_RATE         34 non-null float64
# TUITIONFEE_IN    36 non-null float64
# YEAR             44 non-null object
# dtypes: float64(2), int64(1), object(1)
# memory usage: 1.7+ KB

# %%
md.head(5)
# Out:
#        UNITID  ADM_RATE  TUITIONFEE_IN  YEAR
# 4710   163268       NaN            NaN  1996
# 4721   162928       NaN            NaN  1996
# 11512  163268       NaN            NaN  1997
# 11522  162928       NaN            NaN  1997
# 18048  163268       NaN            NaN  1998

# %%
md.tail(5)
# Out:
#         UNITID  ADM_RATE  TUITIONFEE_IN  YEAR
# 138461  162928    0.1412        48710.0  2015
# 145673  163268    0.5683        11264.0  2016
# 145680  162928    0.1284        50410.0  2016
# 152803  163268    0.6021        11518.0  2017
# 152808  162928    0.1254        52170.0  2017

# %%
md.sample(5)
# Out:
#         UNITID  ADM_RATE  TUITIONFEE_IN  YEAR
# 44219   162928    0.3506        27390.0  2002
# 152803  163268    0.6021        11518.0  2017
# 145680  162928    0.1284        50410.0  2016
# 57521   162928    0.3071        30140.0  2004
# 44210   163268    0.6327         6362.0  2002

# %%
md.isna().sum()
# Out:
# UNITID            0
# ADM_RATE         10
# TUITIONFEE_IN     8
# YEAR              0
# dtype: int64

# %%
# <13>
# Plot the in-state tuition of both UMBC and JHU over the 22 years on the same plot
# This plot will help us compare the two universities.

fig, ax = plt.subplots(figsize=(10,10))  
ax.scatter(md['YEAR'], md['TUITIONFEE_IN'], c=md['UNITID'])
ax.set_title('In-State Tuition for JHU and UMBC 1996-2017', fontsize=14)
ax.set_xlabel('Year', fontsize=14)
ax.set_ylim([0,55000])
ax.set_ylabel('Tuition', fontsize=14)
ax.grid(True)

# %%
# <14> 
# document your observation/conclusion of the plot (use the following Markdown cell)

# %% [markdown]
# #### Based on my observation of the plot,
# #### UMBC appears to have a consistently lower average tuition fee compared to JHU. This makes sense because UMBC is a public university and JHU is private. This makes further sense because I went to JHU and am now in more debt than I care to admit.
# #### UMBC's tuition range over the years is much smaller as well, with very slight increasing rates over time. JHU, on the other hand, has a very steep slope indicating larger tuition raises each year.

# %%
# <15>
# Plot the in-state tuition of both UMBC and JHU over the 22 years on the same plot
# This plot will help us compare the two universities.
md.dropna(subset=["TUITIONFEE_IN"],inplace=True)
md
# Out:
# C:\Users\jay\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
#         UNITID  ADM_RATE  TUITIONFEE_IN  YEAR
# 31038   163268       NaN         5490.0  2000
# 31047   162928       NaN        24930.0  2000
# 37646   163268    0.6551         5910.0  2001
# 37655   162928    0.3431        26210.0  2001
# 44210   163268    0.6327         6362.0  2002
# 44219   162928    0.3506        27390.0  2002
# 50815   163268    0.5757         7388.0  2003
# 50823   162928    0.3060        28730.0  2003
# 57514   163268    0.7014         8020.0  2004
# 57521   162928    0.3071        30140.0  2004
# 64351   163268    0.7143         8520.0  2005
# 64358   162928    0.3509        31620.0  2005
# 71222   163268    0.7153         8622.0  2006
# 71229   162928    0.2792        33900.0  2006
# 78127   163268    0.6895         8708.0  2007
# 78134   162928    0.2571        35900.0  2007
# 85115   163268    0.7174         8780.0  2008
# 85122   162928    0.2609        37700.0  2008
# 92285   163268    0.6890         8872.0  2009
# 92292   162928    0.2782        39150.0  2009
# 99732   163268    0.6589         9171.0  2010
# 99739   162928    0.2225        40680.0  2010
# 107422  163268    0.6081         9467.0  2011
# 107429  162928    0.1940        42280.0  2011
# 115249  163268    0.6035         9764.0  2012
# 115256  162928    0.1843        43390.0  2012
# 123083  163268    0.6315        10068.0  2013
# 123090  162928    0.1813        45470.0  2013
# 130804  163268    0.5961        10384.0  2014
# 130811  162928    0.1608        47060.0  2014
# 138454  163268    0.5942        11006.0  2015
# 138461  162928    0.1412        48710.0  2015
# 145673  163268    0.5683        11264.0  2016
# 145680  162928    0.1284        50410.0  2016
# 152806  163268    0.6021        11518.0  2017
# 152811  162928    0.1254        52170.0  2017

# %%
umbc.reset_index(inplace=True)
umbc.drop(columns=["index", "UNITID", "ADM_RATE"], inplace=True)
umbc.rename(columns={"TUITIONFEE_IN":"UMBC_COST"}, inplace=True)
umbc
# Out:
#     UMBC_COST  YEAR
# 0         NaN  1996
# 1         NaN  1997
# 2         NaN  1998
# 3         NaN  1999
# 4      5490.0  2000
# 5      5910.0  2001
# 6      6362.0  2002
# 7      7388.0  2003
# 8      8020.0  2004
# 9      8520.0  2005
# 10     8622.0  2006
# 11     8708.0  2007
# 12     8780.0  2008
# 13     8872.0  2009
# 14     9171.0  2010
# 15     9467.0  2011
# 16     9764.0  2012
# 17    10068.0  2013
# 18    10384.0  2014
# 19    11006.0  2015
# 20    11264.0  2016
# 21    11518.0  2017

# %%
jhu.reset_index(inplace=True)
jhu.drop(columns=["index", "UNITID", "ADM_RATE"], inplace=True)
jhu.rename(columns={"TUITIONFEE_IN":"JHU_COST"}, inplace=True)
jhu
# Out:
#     JHU_COST  YEAR
# 0        NaN  1996
# 1        NaN  1997
# 2        NaN  1998
# 3        NaN  1999
# 4    24930.0  2000
# 5    26210.0  2001
# 6    27390.0  2002
# 7    28730.0  2003
# 8    30140.0  2004
# 9    31620.0  2005
# 10   33900.0  2006
# 11   35900.0  2007
# 12   37700.0  2008
# 13   39150.0  2009
# 14   40680.0  2010
# 15   42280.0  2011
# 16   43390.0  2012
# 17   45470.0  2013
# 18   47060.0  2014
# 19   48710.0  2015
# 20   50410.0  2016
# 21   52170.0  2017

# %%
both = pd.merge(umbc, jhu, on="YEAR")
both
# Out:
#     UMBC_COST  YEAR  JHU_COST
# 0         NaN  1996       NaN
# 1         NaN  1997       NaN
# 2         NaN  1998       NaN
# 3         NaN  1999       NaN
# 4      5490.0  2000   24930.0
# 5      5910.0  2001   26210.0
# 6      6362.0  2002   27390.0
# 7      7388.0  2003   28730.0
# 8      8020.0  2004   30140.0
# 9      8520.0  2005   31620.0
# 10     8622.0  2006   33900.0
# 11     8708.0  2007   35900.0
# 12     8780.0  2008   37700.0
# 13     8872.0  2009   39150.0
# 14     9171.0  2010   40680.0
# 15     9467.0  2011   42280.0
# 16     9764.0  2012   43390.0
# 17    10068.0  2013   45470.0
# 18    10384.0  2014   47060.0
# 19    11006.0  2015   48710.0
# 20    11264.0  2016   50410.0
# 21    11518.0  2017   52170.0

# %%
md[umbc_change] = md[md["UNITID"] == 163268]["TUITIONFEE_IN"].pct_change()

# %%
both['YEAR']= pd.to_datetime(both['YEAR']) 
both
# Out:
#     UMBC_COST       YEAR  JHU_COST
# 0         NaN 1996-01-01       NaN
# 1         NaN 1997-01-01       NaN
# 2         NaN 1998-01-01       NaN
# 3         NaN 1999-01-01       NaN
# 4      5490.0 2000-01-01   24930.0
# 5      5910.0 2001-01-01   26210.0
# 6      6362.0 2002-01-01   27390.0
# 7      7388.0 2003-01-01   28730.0
# 8      8020.0 2004-01-01   30140.0
# 9      8520.0 2005-01-01   31620.0
# 10     8622.0 2006-01-01   33900.0
# 11     8708.0 2007-01-01   35900.0
# 12     8780.0 2008-01-01   37700.0
# 13     8872.0 2009-01-01   39150.0
# 14     9171.0 2010-01-01   40680.0
# 15     9467.0 2011-01-01   42280.0
# 16     9764.0 2012-01-01   43390.0
# 17    10068.0 2013-01-01   45470.0
# 18    10384.0 2014-01-01   47060.0
# 19    11006.0 2015-01-01   48710.0
# 20    11264.0 2016-01-01   50410.0
# 21    11518.0 2017-01-01   52170.0

# %%
both.set_index("YEAR", inplace=True)
both
# Out:
#             UMBC_COST  JHU_COST
# YEAR
# 1996-01-01        NaN       NaN
# 1997-01-01        NaN       NaN
# 1998-01-01        NaN       NaN
# 1999-01-01        NaN       NaN
# 2000-01-01     5490.0   24930.0
# 2001-01-01     5910.0   26210.0
# 2002-01-01     6362.0   27390.0
# 2003-01-01     7388.0   28730.0
# 2004-01-01     8020.0   30140.0
# 2005-01-01     8520.0   31620.0
# 2006-01-01     8622.0   33900.0
# 2007-01-01     8708.0   35900.0
# 2008-01-01     8780.0   37700.0
# 2009-01-01     8872.0   39150.0
# 2010-01-01     9171.0   40680.0
# 2011-01-01     9467.0   42280.0
# 2012-01-01     9764.0   43390.0
# 2013-01-01    10068.0   45470.0
# 2014-01-01    10384.0   47060.0
# 2015-01-01    11006.0   48710.0
# 2016-01-01    11264.0   50410.0
# 2017-01-01    11518.0   52170.0

# %%
# The end.

# %%
both = both.pct_change()

# %%
both
# Out:
#             UMBC_COST  JHU_COST
# YEAR
# 1996-01-01        NaN       NaN
# 1997-01-01        NaN       NaN
# 1998-01-01        NaN       NaN
# 1999-01-01        NaN       NaN
# 2000-01-01        NaN       NaN
# 2001-01-01   0.076503  0.051344
# 2002-01-01   0.076481  0.045021
# 2003-01-01   0.161270  0.048923
# 2004-01-01   0.085544  0.049078
# 2005-01-01   0.062344  0.049104
# 2006-01-01   0.011972  0.072106
# 2007-01-01   0.009974  0.058997
# 2008-01-01   0.008268  0.050139
# 2009-01-01   0.010478  0.038462
# 2010-01-01   0.033702  0.039080
# 2011-01-01   0.032276  0.039331
# 2012-01-01   0.031372  0.026254
# 2013-01-01   0.031135  0.047937
# 2014-01-01   0.031387  0.034968
# 2015-01-01   0.059900  0.035062
# 2016-01-01   0.023442  0.034900
# 2017-01-01   0.022550  0.034914

# %%
both.dropna(inplace=True)
both
# Out:
#             UMBC_COST  JHU_COST
# YEAR
# 2001-01-01   0.076503  0.051344
# 2002-01-01   0.076481  0.045021
# 2003-01-01   0.161270  0.048923
# 2004-01-01   0.085544  0.049078
# 2005-01-01   0.062344  0.049104
# 2006-01-01   0.011972  0.072106
# 2007-01-01   0.009974  0.058997
# 2008-01-01   0.008268  0.050139
# 2009-01-01   0.010478  0.038462
# 2010-01-01   0.033702  0.039080
# 2011-01-01   0.032276  0.039331
# 2012-01-01   0.031372  0.026254
# 2013-01-01   0.031135  0.047937
# 2014-01-01   0.031387  0.034968
# 2015-01-01   0.059900  0.035062
# 2016-01-01   0.023442  0.034900
# 2017-01-01   0.022550  0.034914

# %%
fig, ax = plt.subplots(figsize=(16,10))
both.plot(ax=ax)
