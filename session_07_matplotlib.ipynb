# %% [markdown]
# <a href="https://colab.research.google.com/github/wcj365/python-stats-dataviz/blob/master/session_07_matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

df = pd.read_csv("fdsfdsfs", userols=["x", "B"])

# %%
x = [1,2,3,4]
y = [10, 15.5, -12, 34]

fig, ax_list = plt.subplots(2,2,figsize=(8,6))
ax_list[1,1].plot(x,y)
fig.show()

# %%
Unemployment_Rate = [6.1,5.8,5.7,5.7,5.8,5.6,5.5,5.3,5.2,5.2]
Stock_Index_Price = [1500,1520,1525,1523,1515,1540,1545,1560,1555,1565]

fig, ax = plt.subplots(figsize=(12,8))
ax.scatter(Unemployment_Rate,Stock_Index_Price)
ax.set_title("Relationship Between Unemployment and Stock Price")
ax.set_xlabel("Unemployment_Rate")
ax.set_ylabel("Stock_Index_Price")
fig.show()

# %%
Country = ['USA','Canada','Germany','UK','France']
GDP_Per_Capita = [45000,42000,52000,49000,47000]

fig, ax = plt.subplots(figsize=(12,8))

ax.bar(Country, GDP_Per_Capita)
ax.set_title("GPD per Capita of Developed Countries")
ax.set_xlabel("Country")
ax.set_ylabel("Per Capita GPD")

fig.show()

# %%
fig.savefig("gdp.pdf", dpi=300)
