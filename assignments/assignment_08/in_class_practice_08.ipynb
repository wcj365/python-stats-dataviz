# %% [markdown]
# <a href="https://colab.research.google.com/github/wcj365/data690fall21/blob/main/assignment_08/in_class_practice_08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # In Class Practice Session 8
# - Name: Jay
# - Date: 10/21/21

# %%
import pandas as pd
import plotly.express as px

# %%
df = pd.read_csv("/content/wdi_data.csv")
df.head()
# Out:
#    Unnamed: 0  Year        value  ...      Region Income Group Lending Type
# 0           0  2015  2087.305323  ...  South Asia   Low income          IDA
# 1           1  2016  1981.118069  ...  South Asia   Low income          IDA
# 2           2  2017  2058.400221  ...  South Asia   Low income          IDA
# 3           3  2018  2082.635648  ...  South Asia   Low income          IDA
# 4           4  2019  2152.366489  ...  South Asia   Low income          IDA
#
# [5 rows x 9 columns]

# %%
df.sample(10)
# Out:
#       Unnamed: 0  Year  ...         Income Group    Lending Type
# 1333        1333  2018  ...  Upper middle income            IBRD
# 3925        3925  2016  ...          High income  Not classified
# 1376        1376  2016  ...          High income  Not classified
# 4188        4188  2019  ...  Upper middle income            IBRD
# 3526        3526  2017  ...  Lower middle income             IDA
# 894          894  2018  ...  Upper middle income            IBRD
# 724          724  2017  ...          High income            IBRD
# 2427        2427  2017  ...  Lower middle income             IDA
# 652          652  2015  ...  Upper middle income             IDA
# 4213        4213  2019  ...  Upper middle income           Blend
#
# [10 rows x 9 columns]

# %%
df_2019 = df.query("Year == 2019")

df_2019.sample(10)
# Out:
#       Unnamed: 0  Year  ...         Income Group    Lending Type
# 3383        3383  2019  ...          High income            IBRD
# 3588        3588  2019  ...  Lower middle income           Blend
# 2042        2042  2019  ...           Low income             IDA
# 3868        3868  2019  ...  Lower middle income           Blend
# 1387        1387  2019  ...          High income  Not classified
# 3943        3943  2019  ...           Low income             IDA
# 1640        1640  2019  ...          High income  Not classified
# 3713        3713  2019  ...  Lower middle income            IBRD
# 4058        4058  2019  ...          High income  Not classified
# 3125        3125  2019  ...          High income  Not classified
#
# [10 rows x 9 columns]

# %%
df_2019 = df_2019.query("indicator in ['SP.DYN.LE00.IN','NY.GDP.PCAP.PP.CD','SP.POP.TOTL']")
#  df_2019 = df_2019[df_2019["indicator"].isin(['SP.DYN.LE00.IN','NY.GDP.PCAP.PP.CD'])]

df_2019
# Out:
#       Unnamed: 0  Year  ...         Income Group    Lending Type
# 4              4  2019  ...           Low income             IDA
# 10            10  2019  ...  Upper middle income            IBRD
# 16            16  2019  ...  Lower middle income            IBRD
# 22            22  2019  ...  Lower middle income            IBRD
# 28            28  2019  ...          High income            IBRD
# ...          ...   ...  ...                  ...             ...
# 3413        3413  2019  ...          High income  Not classified
# 3419        3419  2019  ...  Lower middle income  Not classified
# 3425        3425  2019  ...           Low income             IDA
# 3431        3431  2019  ...  Lower middle income             IDA
# 3437        3437  2019  ...  Lower middle income           Blend
#
# [606 rows x 9 columns]

# %%
df_2019.drop(columns=["Unnamed: 0", "Year"], inplace=True)

df_2019.head()
# Out:
#            value          indicator  ...         Income Group Lending Type
# 4    2152.366489  NY.GDP.PCAP.PP.CD  ...           Low income          IDA
# 10  14230.989507  NY.GDP.PCAP.PP.CD  ...  Upper middle income         IBRD
# 16  11997.337834  NY.GDP.PCAP.PP.CD  ...  Lower middle income         IBRD
# 22   6952.419362  NY.GDP.PCAP.PP.CD  ...  Lower middle income         IBRD
# 28  22460.019253  NY.GDP.PCAP.PP.CD  ...          High income         IBRD
#
# [5 rows x 7 columns]

# %%
df_pivot = df_2019.pivot_table(index=['Country Code','Country Name','Region','Income Group','Lending Type'], columns='indicator', values='value').reset_index()
df_pivot.head()
# Out:
# indicator Country Code Country Name  ... SP.DYN.LE00.IN SP.POP.TOTL
# 0                  ABW        Aruba  ...         76.293    106310.0
# 1                  AFG  Afghanistan  ...         64.833  38041757.0
# 2                  AGO       Angola  ...         61.147  31825299.0
# 3                  ALB      Albania  ...         78.573   2854191.0
# 4                  AND      Andorra  ...            NaN     77146.0
#
# [5 rows x 8 columns]

# %%
fig = px.scatter(
    df_pivot.dropna(),
    x="NY.GDP.PCAP.PP.CD",
    y="SP.DYN.LE00.IN",
    title="Health vs Wealth",
    labels={"SP.DYN.LE00.IN":"Life Expectancy", "NY.GDP.PCAP.PP.CD":"GDP per Capita"},
    color="Region",
    hover_name="Country Name",
    text="Country Name",
    size="SP.POP.TOTL"
)

fig.update_traces(textposition='top center')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="8f6eb8fb-a547-4db5-9149-ac85229d925c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8f6eb8fb-a547-4db5-9149-ac85229d925c")) {
#                     Plotly.newPlot(
#                         '8f6eb8fb-a547-4db5-9149-ac85229d925c',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Region=South Asia<br>GDP per Capita=%{x}<br>Life Expectancy=%{y}<br>SP.POP.TOTL=%{marker.size}<br>Country Name=%{text}", "hovertext": ["Afghanistan", "Bangladesh", "Bhutan", "India", "Sri Lanka", "Maldives", "Nepal", "Pakistan"], "legendgroup": "Region=South Asia", "marker": {"color": "#636efa", "size": [38041757.0, 163046173.0, 763094.0, 1366417756.0, 21803000.0, 530957.0, 28608715.0, 216565317.0], "sizemode": "area", "sizeref": 3494287.5, "symbol": "circle"}, "mode": "markers+text", "name": "Region=South Asia", "showlegend": true, "text": ["Afghanistan", "Bangladesh", "Bhutan", "India", "Sri Lanka", "Maldives", "Nepal", "Pakistan"], "textposition": "top center", "type": "scatter", "x": [2152.3664894209, 4954.7614000529, 12332.5394928352, 6997.8639882409, 13622.8604484357, 20357.009142013998, 4119.9223393551, 4888.8450871345], "xaxis": "x", "y": [64.833, 72.59100000000001, 71.777, 69.656, 76.97800000000001, 78.921, 70.778, 67.273], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Region=Sub-Saharan Africa <br>GDP per Capita=%{x}<br>Life Expectancy=%{y}<br>SP.POP.TOTL=%{marker.size}<br>Country Name=%{text}", "hovertext": ["Angola", "Burundi", "Benin", "Burkina Faso", "Botswana", "Central African Republic", "Cote d'Ivoire", "Cameroon", "Congo, Dem. Rep.", "Congo, Rep.", "Comoros", "Cabo Verde", "Ethiopia", "Gabon", "Ghana", "Guinea", "Gambia, The", "Guinea-Bissau", "Equatorial Guinea", "Kenya", "Liberia", "Lesotho", "Madagascar", "Mali", "Mozambique", "Mauritania", "Mauritius", "Malawi", "Namibia", "Niger", "Nigeria", "Rwanda", "Sudan", "Senegal", "Sierra Leone", "Somalia", "Sao Tome and Principe", "Eswatini", "Seychelles", "Chad", "Togo", "Tanzania", "Uganda", "South Africa", "Zambia", "Zimbabwe"], "legendgroup": "Region=Sub-Saharan Africa ", "marker": {"color": "#EF553B", "size": [31825299.0, 11530577.0, 11801151.0, 20321383.0, 2303703.0, 4745179.0, 25716554.0, 25876387.0, 86790568.0, 5380504.0, 850891.0, 549936.0, 112078727.0, 2172578.0, 30417858.0, 12771246.0, 2347696.0, 1920917.0, 1355982.0, 52573967.0, 4937374.0, 2125267.0, 26969306.0, 19658023.0, 30366043.0, 4525698.0, 1265711.0, 18628749.0, 2494524.0, 23310719.0, 200963603.0, 12626938.0, 42813237.0, 16296362.0, 7813207.0, 15442906.0, 215048.0, 1148133.0, 97625.0, 15946882.0, 8082359.0, 58005461.0, 44269587.0, 58558267.0, 17861034.0, 14645473.0], "sizemode": "area", "sizeref": 3494287.5, "symbol": "circle"}, "mode": "markers+text", "name": "Region=Sub-Saharan Africa ", "showlegend": true, "text": ["Angola", "Burundi", "Benin", "Burkina Faso", "Botswana", "Central African Republic", "Cote d'Ivoire", "Cameroon", "Congo, Dem. Rep.", "Congo, Rep.", "Comoros", "Cabo Verde", "Ethiopia", "Gabon", "Ghana", "Guinea", "Gambia, The", "Guinea-Bissau", "Equatorial Guinea", "Kenya", "Liberia", "Lesotho", "Madagascar", "Mali", "Mozambique", "Mauritania", "Mauritius", "Malawi", "Namibia", "Niger", "Nigeria", "Rwanda", "Sudan", "Senegal", "Sierra Leone", "Somalia", "Sao Tome and Principe", "Eswatini", "Seychelles", "Chad", "Togo", "Tanzania", "Uganda", "South Africa", "Zambia", "Zimbabwe"], "textposition": "top center", "type": "scatter", "x": [6952.4193623685, 783.4519831987, 3426.3296544539003, 2270.4440186964002, 18528.5884353174, 985.1120413522, 5432.9926079949, 3796.3079108328, 1144.3810285221, 4005.3105811735, 3188.8774414629997, 7475.122519809001, 2315.3477301282, 15582.314911655601, 5625.0992202003, 2675.5936951902, 2316.8850302446, 2021.3019428160999, 19285.0362474418, 4512.9818974701, 1488.2014707701, 2693.1983726712, 1686.9799455398002, 2420.1109064117, 1335.7008525106, 5416.8561142439, 23837.4692377116, 1578.7176672666, 10261.5665184184, 1276.2947246347999, 5352.6794230311, 2321.71858979, 4362.6094269231, 3503.6175482752, 1792.5195460287, 903.4176132678999, 4174.7272724355, 8986.419626634399, 28685.0352118539, 1646.4283905401999, ...
