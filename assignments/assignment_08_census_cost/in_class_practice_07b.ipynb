# %% [markdown]
# <a href="https://colab.research.google.com/github/wcj365/data690fall21/blob/main/assignment_07/in_class_practice_07b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # In-Class Practice Session 7
# - Name: Jay
# - Date: 10-14-2021

# %%
import pandas as pd

print("Pandas Version is ", pd.__version__)

import plotly 

print("Plotly Version is", plotly.__version__)

import plotly.graph_objects as go
import plotly.express as px
# Out:
# Pandas Version is  1.1.5
# Plotly Version is 4.4.1

# %%
df = pd.read_csv("/content/wdi_data.csv")
df.head(10)
# Out:
#    Unnamed: 0  Year  ...         Income Group Lending Type
# 0           0  2015  ...           Low income          IDA
# 1           1  2016  ...           Low income          IDA
# 2           2  2017  ...           Low income          IDA
# 3           3  2018  ...           Low income          IDA
# 4           4  2019  ...           Low income          IDA
# 5           5  2020  ...           Low income          IDA
# 6           6  2015  ...  Upper middle income         IBRD
# 7           7  2016  ...  Upper middle income         IBRD
# 8           8  2017  ...  Upper middle income         IBRD
# 9           9  2018  ...  Upper middle income         IBRD
#
# [10 rows x 9 columns]

# %%
df_gdp = df.query("indicator == 'NY.GDP.PCAP.PP.CD'")

df_gdp
# Out:
#       Unnamed: 0  Year  ...         Income Group Lending Type
# 0              0  2015  ...           Low income          IDA
# 1              1  2016  ...           Low income          IDA
# 2              2  2017  ...           Low income          IDA
# 3              3  2018  ...           Low income          IDA
# 4              4  2019  ...           Low income          IDA
# ...          ...   ...  ...                  ...          ...
# 1140        1140  2016  ...  Lower middle income        Blend
# 1141        1141  2017  ...  Lower middle income        Blend
# 1142        1142  2018  ...  Lower middle income        Blend
# 1143        1143  2019  ...  Lower middle income        Blend
# 1144        1144  2020  ...  Lower middle income        Blend
#
# [1145 rows x 9 columns]

# %%
df_ind = df_gdp[df_gdp["Country Code"] == "IND"]

df_ind
# Out:
#      Unnamed: 0  Year  ...         Income Group Lending Type
# 462         462  2015  ...  Lower middle income         IBRD
# 463         463  2016  ...  Lower middle income         IBRD
# 464         464  2017  ...  Lower middle income         IBRD
# 465         465  2018  ...  Lower middle income         IBRD
# 466         466  2019  ...  Lower middle income         IBRD
# 467         467  2020  ...  Lower middle income         IBRD
#
# [6 rows x 9 columns]

# %%
df_bra = df_gdp[df_gdp["Country Code"] == "BRA"]

df_bra
# Out:
#      Unnamed: 0  Year  ...         Income Group Lending Type
# 140         140  2015  ...  Upper middle income         IBRD
# 141         141  2016  ...  Upper middle income         IBRD
# 142         142  2017  ...  Upper middle income         IBRD
# 143         143  2018  ...  Upper middle income         IBRD
# 144         144  2019  ...  Upper middle income         IBRD
# 145         145  2020  ...  Upper middle income         IBRD
#
# [6 rows x 9 columns]

# %%
fig = go.Figure()

trace_ind = go.Bar(      
    x=df_ind["Year"],    
    y=df_ind["value"],
    name="India"
)

fig.add_trace(trace_ind)


trace_brz = go.Bar(      
    x=df_bra["Year"],    
    y=df_bra["value"],
    name="Brazil"
)

fig.add_trace(trace_brz)

fig.update_layout(
    title="India vs Brazil GDP per Capita Over Time",
    xaxis_title="YEAR",
    yaxis_title="GDP per Capita"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f85fd117-4578-4fdd-b3a0-35babcaee0c4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f85fd117-4578-4fdd-b3a0-35babcaee0c4")) {
#                     Plotly.newPlot(
#                         'f85fd117-4578-4fdd-b3a0-35babcaee0c4',
# ...

# %%
df_ind_bra = df_gdp[df_gdp["Country Code"].isin(["IND","BRA"])]

df_ind_bra
# Out:
#      Unnamed: 0  Year  ...         Income Group Lending Type
# 140         140  2015  ...  Upper middle income         IBRD
# 141         141  2016  ...  Upper middle income         IBRD
# 142         142  2017  ...  Upper middle income         IBRD
# 143         143  2018  ...  Upper middle income         IBRD
# 144         144  2019  ...  Upper middle income         IBRD
# 145         145  2020  ...  Upper middle income         IBRD
# 462         462  2015  ...  Lower middle income         IBRD
# 463         463  2016  ...  Lower middle income         IBRD
# 464         464  2017  ...  Lower middle income         IBRD
# 465         465  2018  ...  Lower middle income         IBRD
# 466         466  2019  ...  Lower middle income         IBRD
# 467         467  2020  ...  Lower middle income         IBRD
#
# [12 rows x 9 columns]

# %%
fig = px.bar(
    data_frame=df_ind_bra,
    title="India GDP per Capita Over Time",
    labels={"value":"GDP per Capita", "Year":"YEAR"},
    orientation="v",
    x="Year",
    y="value",
    color="Country Code",
    barmode="group"
)

fig.update_xaxes(tickangle=45)


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="419b0367-c730-4539-bd95-50c4bd60c21e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("419b0367-c730-4539-bd95-50c4bd60c21e")) {
#                     Plotly.newPlot(
#                         '419b0367-c730-4539-bd95-50c4bd60c21e',
# ...
